# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#  <b>Добрый день, Ярослав!</b>
#
# Меня зовут Ксения Цыганова, и я буду комментировать твою работу и помогать тебе сделать ее сильнее. В Практикуме мы общаемся на «ты», но если тебе это будет некомфортно, пожалуйста, скажи, и мы будем обращаться друг к другу на «вы».
#
# Все мои комментарии делятся на три вида:
#
#
# 👍 Здесь все отлично, идем дальше! - <font color='green'> зеленый цвет </font>
#
# 💡 Все хорошо, однако, можно оптимизировать или рассмотреть другие способы (необязательно для исполнения, чтобы пройти дальше) - <font color='gold'>желтый цвет</font>
#
# 🤔 Необходимо внести исправления, без которых я не смогу принять проект - <font color='red'>красный цвет</font>
#
#
# Свои комментарии я буду выделять заголовком «комментарий ревьюера». Пожалуйста, не удаляй их, это поможет сократить время проверки на повторных ревью.Ты также можешь писать свои комментарии к моим и выделять их любым понравившимся способом, отличным от моего. Если у тебя будут возникать вопросы в течение нашей работы, я с радостью на них отвечу.
#
# Цель моего ревью не критика и не возможность дать тебе готовые ответы, это способ привести тебя в нужное русло, чтобы ты смог развить собственные идеи и решения. Твой будущий работодатель будет поступать похожим образом.
#
#    <b>У тебя все получится!</b>

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black">✍Привет! Спасибо за ревью! Бегу смотреть и исправлять ошибки)Мои комментарии будут на синем фоне, как этот. А участки нового кода, всегда между синими линиями</font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет, Ярослав!
#
# Спасибо за разъяснения, договорились!

# %% [markdown]
# <div style="border: solid red; background-color: rgba(50, 115, 220, 0.3); font-size: 16px">
#     Исправления 2 итерации проекта рядом комментариями в красной рамочке

# %% [markdown]
# <hr style="border: 2px solid blue;">

# %%
#some code

# %% [markdown]
# <hr style="border: 2px solid blue;">

# %% [markdown]
# # Прогнозирование оттока клиентов в сети отелей «Как в гостях»

# %% [markdown]
# ### Внесены изменения 2

# %% [markdown]
# ## Описание проекта
# Заказчик исследования - сеть отелей "Как в гостях". Необходимо разработать модель машинного обучния, способную эффективно предсказывать отказ от брони. В случае, если модель предсказывает отказ, клиенту придется внести депозит 80% от стоимости за сутки и стоимость уборки.
# Ключевая метрика - прибыль компании.
# ## Цели
# 1. Разработать систему прогнозирования отказа от брони.
# 2. Данная система должна окупиться за тестовый период.
# ## Описание данных
# * id — номер записи;
# * adults — количество взрослых постояльцев;
# * arrival_date_year — год заезда;
# * arrival_date_month — месяц заезда;
# * arrival_date_week_number — неделя заезда;
# * arrival_date_day_of_month — день заезда;
# * babies — количество младенцев;
# * booking_changes — количество изменений параметров заказа;
# * children — количество детей от 3 до 14 лет;
# * country — гражданство постояльца;
# * customer_type — тип заказчика:
# * Contract — договор с юридическим лицом;
# * Group — групповой заезд;
# * Transient — не связано с договором или групповым заездом;
# * Transient-party — не связано с договором или групповым заездом, но связано с бронированием типа Transient.
# * days_in_waiting_list — сколько дней заказ ожидал подтверждения;
# * distribution_channel — канал дистрибуции заказа;
# * is_canceled — отмена заказа;
# * is_repeated_guest — признак того, что гость бронирует номер второй раз;
# * lead_time — количество дней между датой бронирования и датой прибытия;
# * meal — опции заказа:
# * SC — нет дополнительных опций;
# * BB — включён завтрак;
# * HB — включён завтрак и обед;
# * FB — включён завтрак, обед и ужин.
# * previous_bookings_not_canceled — количество подтверждённых заказов у клиента;
# * previous_cancellations — количество отменённых заказов у клиента;
# * required_car_parking_spaces — необходимость места для автомобиля;
# * reserved_room_type — тип забронированной комнаты;
# * stays_in_weekend_nights — количество ночей в выходные дни;
# * stays_in_week_nights — количество ночей в будние дни;
# * total_nights — общее количество ночей;
# * total_of_special_requests — количество специальных отметок.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отлично, что есть вступительный комментарий.

# %% [markdown]
# ## Шаг 1. Откройте файлы с данными

# %% [markdown]
# ### Импорт библиотек необходимых для анализа

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import (
    accuracy_score,
    recall_score, 
    precision_score,
    f1_score,
    classification_report,
    roc_curve, 
    roc_auc_score,
    confusion_matrix, 
    ConfusionMatrixDisplay
)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
#
# <b>Все отлично!👍:</b>
#
# Отлично, что все импорты собраны в одном месте в начале проекта. Это поможет в случае чего сразу увидеть, какие библиотеки следует доустановить.

# %% [markdown]
# ### Пользовательские функции

# %%
def seson_coef(row):
    month = row['arrival_date_month']
    if month in ['December', 'January', 'February']:
        return 1
    elif month in ['March', 'April', 'May','September', 'October', 'November']:
        return 1.2
    elif month in ['June','July', 'August' ]:
        return 1.4

def room_price(row):
    if row['reserved_room_type'] == 'A':
        return 1000
    elif row['reserved_room_type'] == 'B':
        return 800
    elif row['reserved_room_type'] == 'C':
        return 600
    elif row['reserved_room_type'] == 'D':
        return 550
    elif row['reserved_room_type'] == 'E':
        return 500
    elif row['reserved_room_type'] == 'F':
        return 450
    elif row['reserved_room_type'] == 'G':
        return 350

def service_price(row):
    service_price_list = {
        'A': 400, 
        'B': 350,
        'C': 350,
        'D': 150,
        'E': 150,
        'F': 150,
        'G': 150
        
    }
    return service_price_list[row['reserved_room_type']]

def pr_f1(recall, precision, dot_size=3, alpha=1):
    fig, ax = plt.subplots(1,1, figsize=(12,7))
    x, y = np.meshgrid(np.linspace(0,1, 1000), np.linspace(0, 1, 1000))
    f1 = 2*x*y / (x+y)
    plt.contourf(x,y,f1, levels=20)
    plt.colorbar()
    ax.set_xlabel('Recall', fontsize=16)
    ax.set_ylabel('Precision', fontsize=16)
    ax.set_title('F1-Мера\n', fontsize=16)
    ax.scatter(recall, precision, c='r', linewidth=dot_size, alpha=alpha,\
               label='(reccall, precision) при кросс-валидации модели')
    ax.legend()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Стоит учитывать рекомендации PEP-8 при оформлении проекта, в том числе импортов. С ними можно познакомиться по ссылке: https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black"> Немного не понял, что в импортах не соответствует PEP-8 ( <br>
#     Или понял) Библиотека os - стандартная библиотека python и должна быть первой?
#     </font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера №2<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# "Согласно руководству по написанию кода PEP8 все импорты должны располагаться сразу после комментариев к модулю и строк документации, но перед объявлением констант. При этом группировать их желательно в следующем порядке:
#
# импорты из стандартной библиотеки,
# импорты из сторонних библиотек,
# импорты пользовательских модулей текущего проекта."
#
# И между группами стоит оставлять пустую строку.
#
# То есть импортируешь warnings, далее пустая строка, далее импортируешь, желательно, по алфавиту импорты сторонних библиотек.
#
# Вот еще хорошая статья:
#
# https://okpython.net/python/python_uchebnik/osnovy/moduli_i_pakety_v_python.html
#
# Какие модули входят в стандартную библиотеку можно посмотреть вот здесь:
#
# https://docs.python.org/3/library/exceptions.html#warnings
#
# В данном случае да, стоит ее еще отделить пустой строкой.

# %%
#Настройка pandas
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Загрузка данных

# %%
#open dataset
pth1 = '/datasets/'
pth2 = 'datasets/'

if os.path.exists(pth1):
    try:
        data_train = pd.read_csv('/datasets/hotel_train.csv')
        data_test = pd.read_csv('/datasets/hotel_test.csv')
        print('Датасет успешно считан')
    except:
        print('Возникли проблемы с чтением файлов 1')
elif os.path.exists(pth2):
    try:
        data_train = pd.read_csv('datasets/hotel_train.csv')
        data_test = pd.read_csv('datasets/hotel_test.csv')
        print('Датасет успешно считан')
    except:
        print('Возникли проблемы с чтением файлов 2')
else:
    print('Не найдена необходимая директория')
# Out:
# Датасет успешно считан

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отлично, что используешь конструкцию try/except для загрузки данных.

# %% [markdown]
# ## Шаг 2. Предобработка и исследовательский анализ данных

# %% [markdown]
# ### Проверка утверждений

# %% [markdown]
# Перед началом исследовательского анализа данных проверим следующие утверждения?
# 1. Столбец id уникален для data_train, data_test
# 2. Индексы id в data_train и data_test не имеют пересечений

# %%
print(f'Количество дубликатов в столбце id data_train: {data_train.duplicated().sum()}\n\
Количество дубликатов в столбце id data_test: {data_test.duplicated().sum()}\n\
id data_train и id data_test не имеют пересечений: {set(data_train.id).isdisjoint(set(data_test.id))}')
# Out:
# Количество дубликатов в столбце id data_train: 0
# Количество дубликатов в столбце id data_test: 0
# id data_train и id data_test не имеют пересечений: True

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что проверяешь данные на дубликаты.

# %% [markdown]
# Действительно, id уникален для каждого из датасетов. и не имеет пересечений между собой.
# 1. Запомним индексы (id) каждого из датасетов
# 2. Объединим данные в один большой датасет, проведем исследовательский анализ данных и обработку.
# 3. Затем снова разъединим их на обучающий и проверочный датасет перед началом машинного обучения

# %%
data_train = data_train.set_index('id')
data_test = data_test.set_index('id')

# %%
train_indexes = data_train.index
test_indexes = data_test.index

# %%
data = pd.concat([data_train, data_test])

# %% [markdown]
# ###  Пропуски в датасетах

# %% [markdown]
# Далее проверим данные на наличие пропусков

# %%
print(f'Суммарное количество пропусков во всем датасете: {data.isna().sum().sum()}')
# Out:
# Суммарное количество пропусков во всем датасете: 0

# %% [markdown]
# Пропусков нет вовсе.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что проверяешь данные на пропуски.

# %% [markdown]
# ### Сезонные коэффициенты

# %% [markdown]
# Добавим столбец season_coef со значениями:
# 1.4 - лето
# 1.2 - осень, весна
# 1 - зима

# %%
data['season_coef'] = data.apply(lambda row: seson_coef(row), axis=1)
data.season_coef.unique()
# Out:
# array([1.4, 1.2, 1. ])

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Пользовательские функции можно перенести в начало проекта после импортов и констант.

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black"> Сделано</font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера №2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>

# %% [markdown]
# ### Стоимость номера за ночь и обслуживания

# %%
data.reserved_room_type = data.reserved_room_type.str.replace(' ', '')

# %%
data['room_price'] = data.apply(lambda row: room_price(row), axis=1)
data.room_price.unique()
# Out:
# array([1000,  600,  550,  500,  350,  450,  800], dtype=int64)

# %% [markdown]
# В датасете есть три взаимосвязанных колонки:
# stays_in_weekend_nights, stays_in_week_nights, total_nights
# Логика подсказывает, что:
# $$
# stays\_in\_weekend\_nights + stays\_in\_week\_nights =total\_nights
# $$
# Проверим, так ли это

# %%
(data.stays_in_week_nights + data.stays_in_weekend_nights == data.total_nights).unique()
# Out:
# array([ True])

# %% [markdown]
# Чтобы не попасть в дамми ловушку, столбец total night необходимо удалить

# %%
data = data.drop('total_nights', axis=1)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Да, все верно.

# %% [markdown]
# Вычислим для каждого гостя стоимость обслуживания за все время пребывания

# %%
data['service_price'] = data.apply(lambda row: service_price(row), axis=1)

# %% [markdown]
# ### Выручка компании и прибыль

# %% [markdown]
# Создадим столбец revenue и profit. С полной выручкой и прибылью

# %%
data['revenue'] = (data.stays_in_week_nights + data.stays_in_weekend_nights) *\
    data.room_price * data.season_coef * (1 - data.is_canceled)
data['profit'] = (1 - data.is_canceled) * (data.revenue - data.service_price - \
    data.service_price * ((data.stays_in_week_nights + data.stays_in_weekend_nights) // 2)) \
    - data.is_canceled * (data.service_price + data.room_price * data.season_coef)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Расчеты верные.

# %% [markdown]
# ### Корреляция

# %%
sns.heatmap(data.corr());

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# 1. Для расчета корреляций с учетом категориальных признаков стоит использовать инструменты, рассчитанные на это, например, https://phik.readthedocs.io/en/latest/
#
# 2. Коэффициент корреляции Пирсона (который по дефолту рассчитывается в методе corr), имеет определенные требования к данным:
#
# - характер взаимосвязи двух переменных должен быть линейным и монотонным (коэффициент корреляции Пирсона не может уловить нелинейные зависимости). Поэтому, чтобы проконтроллировать корректность применения коэффициента корреляции Пирсона стоит сначала построить диаграммы рассеяния для переменных.
#
# - распределения обоих переменных, для которых рассчитывается коэффициент должны быть распределены нормально. То есть стоит построить графики распределений для переменных прежде чем изучать корреляцию. Также выбросы, ассиметрия, бимодальность негативно сказываются на адекватности использования среднего значения в качестве некоторого показателя, характеризующего нашу выборку (а коэффициент коррелиции Пирсона основан на среднем значении). Формулу можно посмотреть здесь:
#
# https://studfile.net/preview/2966946/page:34/
#
# Чтобы уменьшить негативное влияние выбросов можно перейти от коэффициента корреляции Пирсона к непараметрическому критерию корреляции - коэффициенту корреляции Спирмена, который уходит от реальных значенийи переходит к рангам.

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black"> Попробую, код ниже. Добавлю импорт тут, надеюсь ничего страшного. Новые кусочки кода, между горизонтальными синими линиями</font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <hr style="border: 2px solid blue;">

# %%
# %%time
# Коэффициент корреляции Спирмена 
import phik
data.phik_matrix().style.background_gradient('coolwarm')
# Out:
# interval columns not set, guessing: ['is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'days_in_waiting_list', 'required_car_parking_spaces', 'total_of_special_requests', 'season_coef', 'room_price', 'service_price', 'revenue', 'profit']
# Wall time: 6.56 s
# <style type="text/css">
# #T_35ac6_row0_col0, #T_35ac6_row0_col27, #T_35ac6_row1_col1, #T_35ac6_row2_col2, #T_35ac6_row3_col3, #T_35ac6_row3_col23, #T_35ac6_row4_col4, #T_35ac6_row5_col5, #T_35ac6_row6_col6, #T_35ac6_row7_col7, #T_35ac6_row8_col8, #T_35ac6_row9_col9, #T_35ac6_row10_col10, #T_35ac6_row11_col11, #T_35ac6_row12_col12, #T_35ac6_row13_col13, #T_35ac6_row14_col14, #T_35ac6_row15_col15, #T_35ac6_row16_col16, #T_35ac6_row17_col17, #T_35ac6_row17_col24, #T_35ac6_row17_col25, #T_35ac6_row18_col18, #T_35ac6_row19_col19, #T_35ac6_row20_col20, #T_35ac6_row21_col21, #T_35ac6_row22_col22, #T_35ac6_row23_col3, #T_35ac6_row23_col23, #T_35ac6_row24_col17, #T_35ac6_row24_col24, #T_35ac6_row24_col25, #T_35ac6_row25_col17, #T_35ac6_row25_col24, #T_35ac6_row25_col25, #T_35ac6_row26_col26, #T_35ac6_row27_col0, #T_35ac6_row27_col27 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col1, #T_35ac6_row24_col9 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_35ac6_row0_col2, #T_35ac6_row0_col9, #T_35ac6_row5_col20, #T_35ac6_row6_col20, #T_35ac6_row7_col16, #T_35ac6_row7_col25, #T_35ac6_row9_col19, #T_35ac6_row9_col27, #T_35ac6_row13_col26, #T_35ac6_row15_col4, #T_35ac6_row17_col14, #T_35ac6_row19_col9, #T_35ac6_row23_col16, #T_35ac6_row23_col24, #T_35ac6_row24_col2, #T_35ac6_row24_col23, #T_35ac6_row27_col15, #T_35ac6_row27_col25 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col3, #T_35ac6_row4_col7, #T_35ac6_row6_col5, #T_35ac6_row6_col17, #T_35ac6_row7_col0, #T_35ac6_row7_col4, #T_35ac6_row11_col13, #T_35ac6_row14_col7, #T_35ac6_row17_col6, #T_35ac6_row22_col2, #T_35ac6_row23_col5, #T_35ac6_row26_col14 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col4, #T_35ac6_row3_col15, #T_35ac6_row3_col17, #T_35ac6_row3_col24, #T_35ac6_row5_col6, #T_35ac6_row9_col13, #T_35ac6_row11_col22, #T_35ac6_row18_col26, #T_35ac6_row19_col21, #T_35ac6_row21_col19, #T_35ac6_row27_col9, #T_35ac6_row27_col16 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col5, #T_35ac6_row0_col25, #T_35ac6_row1_col25, #T_35ac6_row2_col0, #T_35ac6_row2_col5, #T_35ac6_row2_col24, #T_35ac6_row3_col21, #T_35ac6_row4_col18, #T_35ac6_row6_col16, #T_35ac6_row7_col9, #T_35ac6_row13_col10, #T_35ac6_row15_col8, #T_35ac6_row16_col4, #T_35ac6_row17_col18, #T_35ac6_row18_col1, #T_35ac6_row18_col24, #T_35ac6_row19_col13, #T_35ac6_row20_col25, #T_35ac6_row21_col22, #T_35ac6_row23_col14, #T_35ac6_row24_col5, #T_35ac6_row24_col14 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col6, #T_35ac6_row2_col8, #T_35ac6_row2_col13, #T_35ac6_row5_col22, #T_35ac6_row6_col0, #T_35ac6_row8_col2, #T_35ac6_row9_col15, #T_35ac6_row9_col16, #T_35ac6_row10_col1, #T_35ac6_row10_col2, #T_35ac6_row10_col3, #T_35ac6_row10_col4, #T_35ac6_row10_col5, #T_35ac6_row10_col7, #T_35ac6_row10_col12, #T_35ac6_row10_col15, #T_35ac6_row10_col16, #T_35ac6_row10_col19, #T_35ac6_row10_col20, #T_35ac6_row10_col23, #T_35ac6_row11_col18, #T_35ac6_row12_col10, #T_35ac6_row12_col15, #T_35ac6_row12_col16, #T_35ac6_row14_col18, #T_35ac6_row15_col9, #T_35ac6_row15_col10, #T_35ac6_row15_col12, #T_35ac6_row15_col17, #T_35ac6_row15_col18, #T_35ac6_row15_col20, #T_35ac6_row15_col21, #T_35ac6_row15_col24, #T_35ac6_row15_col25, #T_35ac6_row15_col26, #T_35ac6_row15_col27, #T_35ac6_row16_col5, #T_35ac6_row16_col9, #T_35ac6_row16_col10, #T_35ac6_row16_col12, #T_35ac6_row16_col18, #T_35ac6_row16_col25, #T_35ac6_row18_col11, #T_35ac6_row18_col14, #T_35ac6_row18_col15, #T_35ac6_row18_col16, #T_35ac6_row18_col19, #T_35ac6_row18_col23, #T_35ac6_row19_col10, #T_35ac6_row19_col18, #T_35ac6_row21_col8, #T_35ac6_row21_col15, #T_35ac6_row25_col15, #T_35ac6_row25_col16, #T_35ac6_row25_col27 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col7, #T_35ac6_row2_col11, #T_35ac6_row3_col25, #T_35ac6_row4_col17, #T_35ac6_row4_col25, #T_35ac6_row6_col14, #T_35ac6_row8_col19, #T_35ac6_row11_col21, #T_35ac6_row13_col6, #T_35ac6_row13_col18, #T_35ac6_row14_col4, #T_35ac6_row15_col1, #T_35ac6_row19_col7, #T_35ac6_row21_col11, #T_35ac6_row21_col13, #T_35ac6_row22_col4, #T_35ac6_row23_col2, #T_35ac6_row24_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col8, #T_35ac6_row0_col16, #T_35ac6_row5_col8, #T_35ac6_row5_col15, #T_35ac6_row6_col13, #T_35ac6_row8_col0, #T_35ac6_row8_col18, #T_35ac6_row9_col11, #T_35ac6_row11_col9, #T_35ac6_row11_col14, #T_35ac6_row14_col11, #T_35ac6_row17_col4, #T_35ac6_row18_col21, #T_35ac6_row21_col18, #T_35ac6_row26_col5, #T_35ac6_row27_col10 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col10, #T_35ac6_row2_col16, #T_35ac6_row2_col25, #T_35ac6_row3_col18, #T_35ac6_row5_col0, #T_35ac6_row5_col2, #T_35ac6_row5_col18, #T_35ac6_row6_col21, #T_35ac6_row6_col25, #T_35ac6_row7_col2, #T_35ac6_row7_col10, #T_35ac6_row9_col21, #T_35ac6_row10_col11, #T_35ac6_row11_col10, #T_35ac6_row11_col16, #T_35ac6_row14_col17, #T_35ac6_row14_col19, #T_35ac6_row15_col23, #T_35ac6_row16_col11, #T_35ac6_row19_col14, #T_35ac6_row19_col25, #T_35ac6_row21_col9, #T_35ac6_row21_col20, #T_35ac6_row23_col13, #T_35ac6_row25_col19, #T_35ac6_row25_col26 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col11, #T_35ac6_row1_col9, #T_35ac6_row3_col16, #T_35ac6_row4_col21, #T_35ac6_row5_col26, #T_35ac6_row6_col23, #T_35ac6_row7_col22, #T_35ac6_row10_col17, #T_35ac6_row16_col0, #T_35ac6_row16_col27, #T_35ac6_row18_col13, #T_35ac6_row18_col20, #T_35ac6_row18_col25, #T_35ac6_row20_col6, #T_35ac6_row22_col7, #T_35ac6_row22_col14, #T_35ac6_row22_col15, #T_35ac6_row23_col6, #T_35ac6_row24_col10, #T_35ac6_row25_col18, #T_35ac6_row26_col10 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col12 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_35ac6_row0_col13, #T_35ac6_row8_col12, #T_35ac6_row12_col4, #T_35ac6_row12_col24 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col14, #T_35ac6_row8_col26, #T_35ac6_row13_col11, #T_35ac6_row17_col21, #T_35ac6_row20_col24, #T_35ac6_row22_col11, #T_35ac6_row22_col17, #T_35ac6_row23_col8, #T_35ac6_row23_col11, #T_35ac6_row24_col20 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col15, #T_35ac6_row0_col17, #T_35ac6_row4_col16, #T_35ac6_row8_col5, #T_35ac6_row8_col10, #T_35ac6_row10_col18, #T_35ac6_row11_col2, #T_35ac6_row14_col6, #T_35ac6_row15_col3, #T_35ac6_row16_col1, #T_35ac6_row16_col21, #T_35ac6_row17_col0, #T_35ac6_row18_col10, #T_35ac6_row18_col27, #T_35ac6_row20_col18, #T_35ac6_row21_col16, #T_35ac6_row23_col17 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col18, #T_35ac6_row1_col17, #T_35ac6_row2_col1, #T_35ac6_row4_col6, #T_35ac6_row4_col24, #T_35ac6_row7_col19, #T_35ac6_row7_col23, #T_35ac6_row11_col7, #T_35ac6_row11_col23, #T_35ac6_row13_col21, #T_35ac6_row13_col22, #T_35ac6_row19_col26, #T_35ac6_row22_col1, #T_35ac6_row22_col13, #T_35ac6_row25_col13 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col19, #T_35ac6_row8_col3, #T_35ac6_row11_col19, #T_35ac6_row13_col15, #T_35ac6_row14_col20, #T_35ac6_row19_col11, #T_35ac6_row20_col22, #T_35ac6_row26_col3 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col20, #T_35ac6_row4_col20, #T_35ac6_row26_col22 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col21, #T_35ac6_row3_col8, #T_35ac6_row11_col8, #T_35ac6_row17_col26, #T_35ac6_row19_col5, #T_35ac6_row24_col21, #T_35ac6_row26_col11, #T_35ac6_row27_col19 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_35ac6_row0_col22, #T_35ac6_row12_col19, #T_35ac6_row19_col12 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_35ac6_row0_col23, #T_35ac6_row2_col10, #T_35ac6_row2_col26, #T_35ac6_row5_col16, #T_35ac6_row14_col2, #T_35ac6_row15_col2, #T_35ac6_row15_col22, #T_35ac6_row16_col7, #T_35ac6_row16_col26, #T_35ac6_row17_col15, #T_35ac6_row18_col3, #T_35ac6_row18_col4, #T_35ac6_row18_col6, #T_35ac6_row21_col3, #T_35ac6_row21_col5, #T_35ac6_row21_col23, #T_35ac6_row25_col5, #T_35ac6_row25_col7

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black"> Действительно, появились категориальные параметры, сразу можно заметить связь отмены со страной. Буду пользоваться этим коэффициентом </font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <hr style="border: 2px solid blue;">

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера №2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>

# %% [markdown]
# Выводы:
# 1. Сильная линейная связь между выручкой и прибылью с клиента (не самый интересный факт, ввиду очевидности)
# 2. Средняя связь между прибылью и количеством дней в номере (тоже предсказумое)
# 3. Есть средняя связь между повторным бронированием и тем, что гость не отменял предыдущее бронирование
# 4. Найдена средняя связь между страной бронирования и отменой брони

# %% [markdown]
# ### Типы данных

# %% [markdown]
# Приведем данные к логичному типу

# %%
data.loc[:, ['adults', 'children', 'babies']] = data.loc[:, ['adults', 'children', 'babies']].astype('int')

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Также можно исследовать данные на аномальные значения.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Кроме того стоит убрать неявные дубликаты в строковых данных.

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black">Приступаю</font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера №2<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Здесь под неявными дубликатами в строковых данных я имела в виду значения в столбце meal, содержащие лишние пробелы (ниже написала где).

# %% [markdown]
# <hr style="border: 2px solid blue;">

# %% [markdown]
# ### Поиск аномальных значений

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black"> Внимательно посмотрел свои гистограммы по данным типа int. Аномальными показались следующие значения: <br>
#     1. 0 Взрослых <br>
#     2. 9 или 10 младенцев</font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера №2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>

# %%
data.adults.unique()
# Out:
# array([1, 2, 3, 4, 0])

# %%
data.babies.unique()
# Out:
# array([ 0,  1,  2, 10,  9])

# %%
print(f'Количесто строк, где 0 взрослых или младенцев больше 8: \
{len(data.loc[(data.adults  == 0) | (data.babies > 8)])} \n\
Доля относительно датасета: {len(data.loc[(data.adults  == 0) | (data.babies > 8)]) / len(data):.1%}')
# Out:
# Количесто строк, где 0 взрослых или младенцев больше 8: 237
# Доля относительно датасета: 0.2%

# %%
# Удаляем данные с аномальными значениями: 
data = data.loc[~((data.adults  == 0) | (data.babies > 8))]

# %% [markdown]
# ### Поиск неявных дубликатов

# %%
pd.DataFrame({'Количество полных дубликатов': 
              [data.duplicated().sum(),data_train.duplicated().sum(),data_test.duplicated().sum() ],
              'Количество дубликатов без lead_time':  \
              [data.drop('lead_time', axis=1).duplicated().sum(),\
               data_train.drop('lead_time', axis=1).duplicated().sum(),\
               data_test.drop('lead_time', axis=1).duplicated().sum() ]}, 
             index=['data', 'data_train', 'data_test'])
# Out:
#             Количество полных дубликатов  Количество дубликатов без lead_time
# data                               29088                                31532
# data_train                         21377                                23080
# data_test                           7717                                 8458

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black">Либо это ошибка, либо треть нашего датасета это дубликаты. Сбрасываю их</font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %%
data = data.loc[~data.drop('lead_time', axis=1).duplicated(keep='first')]

# %% [markdown]
# <hr style="border: 2px solid blue;">

# %% [markdown]
# ### Распределение величин

# %% [markdown]
# #### float

# %% [markdown]
# Посмотрим как распределены вещественные параметры

# %%
numeric_columns = list(data.dtypes.loc[(data.dtypes == 'float64')].index)
fig, ax = plt.subplots(2,2, figsize=(17, 6))
for index, column in enumerate(numeric_columns):
    data.loc[:, column].plot(kind='box', title=column, ax=ax[index //2, index % 2], vert=False)

# %% [markdown]
# #### object

# %% [markdown]
# Серьезных выбросов, не обнаружено
#
# Исследуем распределение категориальных  переменных

# %%
categorical_columns = list(data.dtypes.loc[(data.dtypes == 'object')].index)
fig, ax = plt.subplots(2,3, figsize=(17, 14))
for index, column in enumerate(categorical_columns[:]):
    data.loc[:, [column, 'is_canceled']]\
        .pivot_table(index=column, values='is_canceled', aggfunc=['count', 'sum'])\
            .sort_values(by=('count', 'is_canceled'), ascending=False)[:15]\
                .plot(kind='bar', legend=False, title=column, ax=ax[index // 3, index%3], rot=45, xlabel='')
    ax[index // 3, index%3].legend(['Количество клиентов', 'Количество отмен'])

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера №2<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Посмотри, пожалуйста, вот здесь в столбце meal на графике, какие есть уникальные значения. Там явно лишние проблемы в данных, и появляется в связи с этим дублирование.

# %% [markdown]
# <div style="border: solid red; background-color: rgba(50, 115, 220, 0.3); font-size: 18px">
#     Поправляю meal

# %% [markdown]
# ### Обработка meal

# %%
data.meal.unique()
# Out:
# array(['BB       ', 'FB       ', 'HB       ', 'SC       ', 'SC'],
#       dtype=object)

# %% [markdown]
# Проблема обнаружена. Исправляю

# %%
data.meal = data.meal.str.strip()

# %%
data.meal.unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC'], dtype=object)

# %% [markdown]
# Теперь в столбце meal только 4 значения без пробелов

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отлично, что анализируешь данные с точки зрения была отменена бронь или нет.

# %% [markdown]
# Анализируя полученные гистограммы можно сделать ряд выводов:
# 1. Сезонные коэффициенты выбраны логично
# 2. Наиболее популярный тип питания: BB = включен завтрак
# 3. Вероятно наш отель расположен в Португалии. Так как большинство туристов именно оттуда. Также отель пользуется популярностью у других Европейских стран. Визуально кажется, что Португальцы чаще других отменяют бронирование.
# 4. Чаще всего отель бронируют через турагента или туроператора (TA/ TO). Реже напрямую
# 5. Наиболее популярные тип номера "A" - наиболее дорогой
# 6. Чаще всего это бронирование не связано с договором или групповым заездом

# %% [markdown]
# #### int

# %%
int_columns = list(data.dtypes.loc[(data.dtypes == 'int64')].index)[1:]
fig, ax = plt.subplots(len(int_columns)//3 + 1,3, figsize=(17, 25))
plt.subplots_adjust(wspace=0.2, hspace=0.3)
for index, column in enumerate(int_columns):
    data.loc[:, [column, 'is_canceled']]\
        .pivot_table(index=column, values='is_canceled', aggfunc=['count', 'sum'])\
            .sort_values(by=('count', 'is_canceled'), ascending=False)[:15]\
                .plot(kind='bar', legend=False, title=column, ax=ax[index // 3, index%3], rot=45, xlabel='')
    ax[index // 3, index%3].legend(['Количество клиентов', 'Количество отмен'])
    ax[index // 3, index%3].set_ylabel('Количество')

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Также у всех графиков стоит добавить подписи осей, кроме того стоит расширить отступы мжеду ними, чтобы все было читаемо.

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black">Добавил подпись к вертикальной оси, а горизонтальная <code>xlabel</code> будет лишь дублировать название <code>title</code>. Немного раздвинул графики, чтобы текст не перекрывался</font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера №2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Здесь код выдает ошибку, пожалуйста, поправь.
#
# Пока посмотрю дальше без аутпута

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black">Крайне странно, я выполняю проект локально в Visual Code, там все работает и ничего не падает. Видимо разные версии питона или библиотек. <br>
#         При этом как ни странно код выводит все гистограммы (что и должен) и выдает ошибку <br><br>
#     P.S. Понял в чем ошибка, колонок 17, а сетка 5x3. Сделаю чтобы, сетка настраивалась автоматически
#     </font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера №2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>

# %% [markdown]
# ### Анализ портрета ненадежного заемщика

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black">После сброса дубликатов многие выводы придется поправить. </font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# #### Lead_time

# %% [markdown]
# Исследуем, как вероятность отмены зависит от времени до бронирования:
# 1. Поделим времена бронирования на децили.
# 2. Построим стобчатую гистограмму среднего значения `is_canceled` в каждом дециле.

# %%
pd.concat([pd.qcut(data.lead_time, q=10), data.is_canceled],axis=1)\
    .pivot_table(index='lead_time', values='is_canceled')\
        .plot(kind='bar', rot=45, \
            title='Вероятность отмены бронирования от времени до заезда',\
                xlabel='Временные интервалы', ylabel='Вероятность отмены');

# %% [markdown]
# **Вероятность отмены брони растет с увеличением срока до заезда в отель**

# %% [markdown]
# #### arrival_date_month

# %% [markdown]
# Исследуем, как влияет месяц заезда на отмены

# %%
data.pivot_table(index='arrival_date_month', values='is_canceled', aggfunc='mean')\
    .sort_values(by='is_canceled', ascending=False)\
        .plot(kind='bar', rot=45, title='Вероятность отмены бронирования от месяца заезда');

# %% [markdown]
# **В сезонные месяцы вероятность отмены несколько выше, чем в зимний период**

# %% [markdown]
# #### adults, children, babies

# %%
data.pivot_table(index='adults', values='is_canceled')\
    .plot(kind='bar', rot=0, grid=True, title='Вероятность отмены от количества взрослых');

# %%
data.pivot_table(index='adults', values='is_canceled', aggfunc=['mean', 'count'])
# Out:
#               mean       count
#        is_canceled is_canceled
# adults
# 1         0.197556       12604
# 2         0.291108       48920
# 3         0.329790        4327
# 4         0.238095          21

# %% [markdown]
# **Приезжающие парами отменяют бронирование чаще, по сравнению с одиночным заездом, при этом наиболее популярные варианты бронирования - 1 взрослый или 2 взрослых. По остальным категориям данных мало**

# %%
data.pivot_table(index='children', values='is_canceled', aggfunc=['mean', 'count'])
# Out:
#                 mean       count
#          is_canceled is_canceled
# children
# 0           0.270947       60761
# 1           0.300476        3358
# 2           0.394374        1742
# 3           0.363636          11

# %% [markdown]
# **По количество детей достаточно сложно сделать вывод, подавляющее большинство гостей без детей**

# %%
data.pivot_table(index='babies', values='is_canceled', aggfunc=['mean', 'count'])
# Out:
#               mean       count
#        is_canceled is_canceled
# babies
# 0         0.276776       65255
# 1         0.167213         610
# 2         0.000000           7

# %% [markdown]
# **С младенцеми путешествуют редко, данных недостаточно для анализа**

# %% [markdown]
# #### meal

# %%
data.pivot_table(index='meal', values='is_canceled',  aggfunc=['mean', 'count'])
# Out:
#             mean       count
#      is_canceled is_canceled
# meal
# BB      0.263448       51642
# FB      0.292683         164
# HB      0.269998        5063
# SC      0.349106        9003

# %% [markdown]
# Наиболее популярные типы питания:
# 1. Включен завтра (BB)
# 2. Без дополнительных опций (SC)
# 3. Завтрак и обед (HB)
# Сделаем анализ по ним

# %%
data.pivot_table(index='meal', values='is_canceled')
# Out:
#       is_canceled
# meal
# BB       0.263448
# FB       0.292683
# HB       0.269998
# SC       0.349106

# %%
data.pivot_table(index='meal', values='is_canceled').iloc[[0,2,3]].plot(kind='bar', rot=0);

# %% [markdown]
# **Разница в типах питания несущественная**

# %% [markdown]
# #### country

# %% [markdown]
# В графе country много различных стран. При этом 95 % посетителей приходится на 16 стран. Анализируем их.
# Также это позволит не плодить огромное количество dummy переменных.

# %%
popular_countries = data.country.value_counts(normalize=True)\
    .loc[data.country.value_counts(normalize=True).cumsum() < 0.95].index
popular_countries
# Out:
# Index(['PRT', 'GBR', 'FRA', 'ESP', 'DEU', 'ITA', 'IRL', 'BEL', 'BRA', 'NLD',
#        'USA', 'CHE', 'AUT', 'CN', 'CHN', 'SWE', 'POL', 'RUS', 'NOR', 'ROU',
#        'FIN', 'ISR', 'DNK', 'AUS', 'LUX'],
#       dtype='object')

# %%
data.country = data.country.where(data.country.isin(popular_countries), 'non_popular')

# %%
data.pivot_table(index='country', values='is_canceled')\
    .sort_values(by='is_canceled', ascending=False).plot(kind='bar', figsize=(15,5), rot=45);

# %% [markdown]
# **Чаще всех отменяют жители Китая и Бразилии**

# %% [markdown]
# #### distribution_channel

# %%
data.pivot_table(index='distribution_channel', values='is_canceled', aggfunc=['mean', 'count'])\
    .sort_values(by=('mean', 'is_canceled'), ascending=False)
# Out:
#                             mean       count
#                      is_canceled is_canceled
# distribution_channel
# TA/TO                   0.308729       53108
# GDS                     0.181818         165
# Direct                  0.141397        8805
# Corporate               0.129678        3794

# %% [markdown]
# **Наиболее популярный канал дистрибуции - через туроператора, по нему же чаще всего происходят отмены. Реже всего люди отменяют, если выбрали отель напрямую.**

# %% [markdown]
# #### is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, booking_changes

# %%
data.loc[:, ['is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', \
    'booking_changes', 'is_canceled']].corr()['is_canceled']\
        .to_frame().style.background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_eb106_row0_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_eb106_row1_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_eb106_row2_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_eb106_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_eb106_row4_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eb106">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb106_level0_col0" class="col_heading level0 col0" >is_canceled</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb106_level0_row0" class="row_heading level0 row0" >is_repeated_guest</th>
#       <td id="T_eb106_row0_col0" class="data row0 col0" >-0.080984</td>
#     </tr>
#     <tr>
#       <th id="T_eb106_level0_row1" class="row_heading level0 row1" >previous_cancellations</th>
#       <td id="T_eb106_row1_col0" class="data row1 col0" >0.051329</td>
#     </tr>
#     <tr>
#       <th id="T_eb106_level0_row2" class="row_heading level0 row2" >previous_bookings_not_canceled</th>
#       <td id="T_eb106_row2_col0" class="data row2 col0" >-0.049375</td>
#     </tr>
#     <tr>
#       <th id="T_eb106_level0_row3" class="row_heading level0 row3" >booking_changes</th>
#       <td id="T_eb106_row3_col0" class="data row3 col0" >-0.086643</td>
#     </tr>
#     <tr>
#       <th id="T_eb106_level0_row4" class="row_heading level0 row4" >is_canceled</th>
#       <td id="T_eb106_row4_col0" class="data row4 col0" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Линейной зависимости между параметрами нет**

# %% [markdown]
# #### reserved_room_type

# %%
data.pivot_table(index='reserved_room_type', values='is_canceled', aggfunc=['mean', 'count'])
# Out:
#                           mean       count
#                    is_canceled is_canceled
# reserved_room_type
# A                     0.265851       45014
# B                     0.299301         715
# C                     0.297619         420
# D                     0.303811       13515
# E                     0.261622        3700
# F                     0.297167        1659
# G                     0.341578         849

# %% [markdown]
# **Чаще всего люди бронируют категории номеров A и D. При этом большая часть отмен бронирований приходится на номера типа А**

# %% [markdown]
# #### days_in_waiting_list

# %%
print(f'Количество клиентов, ожидающих подтверждение больше 0 дней: {(data.days_in_waiting_list != 0).sum()}')
# Out:
# Количество клиентов, ожидающих подтверждение больше 0 дней: 655

# %% [markdown]
# Количество клиентов, ожидающих подтверждение больше 0 дней совсем немного в рамках нашего датасета. Сравним их с основной группой, получающих подвтерждение сразу

# %%
waiting = data.query('days_in_waiting_list != 0').is_canceled.mean()
non_waiting = data.query('days_in_waiting_list == 0').is_canceled.mean()
print(f'Отмен бронирований среди получающих подтверждение бронирования с задержкой: {waiting:.1%}\n\
Отмен бронирований среди получающих подтверждение бронирования без задержки: {non_waiting:.1%}')
# Out:
# Отмен бронирований среди получающих подтверждение бронирования с задержкой: 39.2%
# Отмен бронирований среди получающих подтверждение бронирования без задержки: 27.5%

# %% [markdown]
# **Пользователей лучше не заставлять ждать - им это не нравится**

# %% [markdown]
# #### customer_type

# %%
data.pivot_table(index='customer_type', values='is_canceled', aggfunc=['mean', 'count'])
# Out:
#                        mean       count
#                 is_canceled is_canceled
# customer_type
# Contract           0.185734        2159
# Group              0.065217         414
# Transient          0.298817       55124
# Transient-Party    0.154495        8175

# %% [markdown]
# **Физлица основные постояльцы нашего отеля, остальные категории покупателей представлены слабо для анализа**

# %% [markdown]
# ## Вывод по блоку "Исследовательский анализ данных"
#
# * Столбец id уникален, данные объединены и обработаны вместе
# * В датасете отсутствуют пропуски
# * В датасете обнаружены аномальные значения в колонке `babies` (9 и 10 детей), данные очищены
# * Сезонные коэффициенты выбраны логично
# * Вероятно наш отель расположен в Португалии. Так как большинство туристов именно оттуда.
# * Наиболее популярные тип номера "A" - наиболее дорогой
# * Чаще всего это бронирование не связано с договором или групповым заездом

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>

# %% [markdown]
# ## Шаг 3. Формулировка ML-задачи на основе бизнес-задачи

# %% [markdown]
# Разработка модели машинного обучения, способной прогнозировать необходимость введения депозита для клиента при бронировании номера. <br>
#
# Обязательным условием является повышение прибыли больше, чем на 400_000 руб (стоимость разработки) за тестовый период.

# %%
data_train = data.loc[data.index.isin(train_indexes)]
data_test = data.loc[data.index.isin(test_indexes)]

# %%
print(f'Прибыль компании в тестовый период до внедрения машинного обучения: {data_test.profit.sum():,.0f}\n\
Выручка компании в тестовый период до внедрения машинного обучения: {data_test.revenue.sum():,.0f}\n\
Количество клиентов отменяющих бронь: {data_test.is_canceled.mean():.1%}')
# Out:
# Прибыль компании в тестовый период до внедрения машинного обучения: 31,765,140
# Выручка компании в тестовый период до внедрения машинного обучения: 53,824,360
# Количество клиентов отменяющих бронь: 31.3%

# %% [markdown]
# Почти треть выручки пропадает из-за клиентов отменивших бронь!

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что рассчитываешь прибыль на тестовых данных.

# %% [markdown]
# ## Вывод по блоку "Формулировка ML задачи"
# * Перед нами задача бинарной классификации
# * Основной метрикой является высокая прибыль компании

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Здесь стоит добавить анализ баланса классов в целевой переменной.
#
# Кроме того стоит написать обоснование выьора метрики, с помощью которой ты будешь оценивать модели и подбирать гиперпараметры.

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black">Приступаю</font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <hr style="border: 2px solid blue;">

# %%
data_train.is_canceled.value_counts(normalize=True)\
.plot(kind='bar', rot=0, figsize=(7,5),\
      title='Сравнение баланса классов отменяющих бронь', ylabel='Доля отменяющих бронь', xlabel='Класс');

# %% [markdown]
# Цитата:
# <blockquote>Основная бизнес-метрика для любой сети отелей — её прибыль. Прибыль отеля — это разница между стоимостью номера за все ночи и затраты на обслуживание: как при подготовке номера, так и при проживании постояльца.
# </blockquote>

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black">Возникает вопрос. Мы проходили метрики оценки качества моделей машинного обучения: accuracy, precision, recall, f1 и тд. При этом в данном проекте изначально я решил ввести как основную метрику: прибыль компании. Лучшая модель та, которая показала максимальную прибыль на обучающих данных. Допустима ли такая логика, или пользоваться общепринятыми? <br>
#     Я поправлю код и выведу  лучшие модели с точки зрения следующих метрик: <br>
#     1. Лучшая с точки зрения прибыли на обучабщих данных. Обоснование: так как ключевая бизнес метрика это прибыль <br>
#     2. Лучшая с точки зрения f1-меры. Потому что, такая модель старается максимизировать одновременно и precision и recall.
#     <br><br>
#     P.S. Решил все модели анализировать с точки зрения f-1 меры</font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера №2<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Это интересный подход, можно писать кастомные метрики и функции потерь, такая практика существует, но тогда они должны быть оформлены таким образом, чтобы можно было их использовать в процессе подбора гиперпараметров, а также для оценки моделей в процессе анализа.

# %% [markdown]
# <hr style="border: 2px solid blue;">

# %% [markdown]
# ## Шаг 4. Разработка модели ML

# %% [markdown]
# ### Dummy переменные

# %%
data = pd.get_dummies(data, drop_first=True)

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# В теории тренажера в данный момент предлагается использовать get_dummies, однако, это впоследствии приводит к сложностям поэтому стоит использовать класс <a href="https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html">OHE из sklearn</a>. По аналогии с масштабированием делать fit только на трейне, а transform на всех выборках.
# <hr>
# get_dummies подходит для анализа данных, а для машинного обучения более предпочтителен OHE, т.к. он позоволяет избежать ряд ошибок при обучении моделей, в том числе может работать с неизвестными ранее уровнями категорий, которых не было изначально (например, если появится еще одна модель машины).
#
# get_dummies также нельзя использовать вместе с pipeline, column_transformer, ecли появляется новая выборка и ее нужно кодировать, то обязательно стоит выполнить проверку, чтобы получившиеся фичи были такие же.
#
# Посмотреть более подробно, как использовать OneHotEncoder можно здесь:
#
# https://colab.research.google.com/drive/1_gAMXcQKoCShB_l8FNtYEejMnosm9mvt?usp=sharing

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black">В следующих проектах буду использовать OHE! <br> Спасибо большое за ссылку на colab.  Могу я попросить еще парочку подобных блокнотов по темам на твое усмотрение? </font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера №2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Не за что!
#
# Да, конечно, попробую отыскать что-то еще интересное. Отправлю либо на следующее ревью, либо передам через куратора.

# %% [markdown]
# Перед нами задачи классификации - необходимо предсказывать столбец `is_canceled` по остальным.
# Проверять на эффективность будем три модели:
# 1. Логистическая регрессия
# 2. Случайный лес
# 3. Модель максимальной прибыли
#
# Ключевая метрика: Прибыль компании и f1-score

# %% [markdown]
# Определяем признаки и цели. Сбрасываем созданные колонки из признаков

# %%
data_test_target = data.loc[data.index.isin(test_indexes)].is_canceled
data_test_features = data.loc[data.index.isin(test_indexes)].drop(['is_canceled', 'season_coef', 'room_price', 'revenue', 'profit'], axis=1)
data_train_target = data.loc[data.index.isin(train_indexes)].is_canceled
data_train_features = data.loc[data.index.isin(train_indexes)].drop(['is_canceled', 'season_coef', 'room_price', 'revenue', 'profit'], axis=1)

# %% [markdown]
# ### Разбиваем на обучающую и валидационную выборки

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Так как модели должны быть обучены и оценены с помощью кросс-валидации, то необязательно выделять валидационную выборку, чтобы модели досталось больше данных для обучения.

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black">Перепишу моделирование используя технику кросс-валидации</font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера №2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>

# %% [markdown]
# ### Логистическая регрессия

# %% [markdown]
# <div style="border: solid red 2px; background-color: rgba(50, 115, 220, 0.3); font-size: 18px">
#     Логистическая регрессия переписана, с перебором по гиперпараметрам

# %%
def features_scalling(features_train, features_test):
    scaler = StandardScaler()
    numeric_columns = list(features_train.dtypes.loc[(features_train.dtypes == 'float64') | \
         (features_train.dtypes == 'int64') | (features_train.dtypes == 'int32') | \
                                                     (features_train.dtypes == 'uint8')].index)
    scaler.fit(features_train.loc[:, numeric_columns])
    features_train.loc[:, numeric_columns] = pd.DataFrame(scaler.transform(features_train.loc[:, numeric_columns]),\
                                    index=features_train.index, columns=numeric_columns)
    features_test.loc[:, numeric_columns] = pd.DataFrame(scaler.transform(features_test.loc[:, numeric_columns]), \
                                     index=features_test.index, columns=numeric_columns)
    return features_train, features_test

# %%
def learn_log_regr(features_train, target_train, features_test, target_test):
    #Модель будет рассчитывать f1-score, precision, recall
    # Масштабируем данные на обучающей выборке, применяем к тестовой
    features_train, features_test = features_scalling(features_train, features_test)
    # Вводим константы для сохранения параметров
    best_f1_score =  0
    best_scores = []
    best_log_model = None
    best_c = 0
    # Метрики, которые будем рассчитывать
    scoring = { 'f1-score': 'f1',
                'recall': 'recall',
                'presicion': 'precision'}
    for c in tqdm(np.linspace(0.5, 3, 10)):
        #Инициализируем модель:
        model = LogisticRegression(random_state=42, C=c,
                                        max_iter=1000, class_weight='balanced')
            
        scores = cross_validate(model, features_train, target_train, cv=5, scoring=scoring)
        if scores['test_f1-score'].mean() > best_f1_score:
                    best_f1_score = scores['test_f1-score'].mean()
                    best_log_model = model
                    best_scores = scores
                    best_c = c
    print(f'Лучший C параметр: {best_c:.2f}')
    return pd.DataFrame(scores)

# %%
scores_log_regr = learn_log_regr(data_train_features, data_train_target, data_test_features, data_test_target) 
scores_log_regr
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:34<00:00,  3.49s/it]
# Лучший C параметр: 2.44
#    fit_time  score_time  test_f1-score  test_recall  test_presicion
# 0  0.709159    0.008002       0.608782     0.713951        0.530619
# 1  0.651720    0.007002       0.291147     0.333333        0.258439
# 2  0.668626    0.008002       0.177515     0.210674        0.153374
# 3  0.684205    0.007002       0.251152     0.421077        0.178941
# 4  0.497111    0.008002       0.407721     0.731742        0.282589

# %%
scores_log_regr.mean().to_frame().rename(columns={0: 'Среднее значение'}).style.format('{:.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_2ed06">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ed06_level0_col0" class="col_heading level0 col0" >Среднее значение</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ed06_level0_row0" class="row_heading level0 row0" >fit_time</th>
#       <td id="T_2ed06_row0_col0" class="data row0 col0" >0.64</td>
#     </tr>
#     <tr>
#       <th id="T_2ed06_level0_row1" class="row_heading level0 row1" >score_time</th>
#       <td id="T_2ed06_row1_col0" class="data row1 col0" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_2ed06_level0_row2" class="row_heading level0 row2" >test_f1-score</th>
#       <td id="T_2ed06_row2_col0" class="data row2 col0" >0.35</td>
#     </tr>
#     <tr>
#       <th id="T_2ed06_level0_row3" class="row_heading level0 row3" >test_recall</th>
#       <td id="T_2ed06_row3_col0" class="data row3 col0" >0.48</td>
#     </tr>
#     <tr>
#       <th id="T_2ed06_level0_row4" class="row_heading level0 row4" >test_presicion</th>
#       <td id="T_2ed06_row4_col0" class="data row4 col0" >0.28</td>
#     </tr>
#   </tbody>
# </table>

# %%
pr_f1(list(scores_log_regr.loc[:, 'test_recall']),list(scores_log_regr.loc[:, 'test_presicion']) )
# Out:
# C:\Users\miros\AppData\Local\Temp\ipykernel_16564\1885180191.py:42: RuntimeWarning: invalid value encountered in true_divide
#   f1 = 2*x*y / (x+y)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Модели стоит оценивать по результатам кросс-валидации. Кроме того в методе score идет рассчет accuracy, что в условиях дисбаласнса не является объективной метрикой.

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black">При проведении кросс валидации на обучающей выборке, модель оказалась неустойчивой, разброс значений основных метрик (f1, recall, precision) велик. Что можно видеть из графика выше<br>
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Красивый график, молодец!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Расчет прибыли после внедрения депозита мы делаем для лучшей модели, выбранной по результатам кросс-валидации.

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black">Убрал расчет прибыли, продолжаю исследовать другие модели.<br>
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black">Мини вопрос к будущему комметарию:<br><br>
#         <div class='temp', style='background-color: white;'>
#        <blockquote>
#         <b>На доработку🤔:</b>
# Как минимум для 2х моделей стоит подобрать как минимум по 2 гиперпарметра.<br>
#        </blockquote></div><br>
#         Исследуя модель логистической регрессии ранее я пробовал перебирать гиперпараметр <code>solver</code>
#         Что то вроде:
#         <code>
#             for solv in ['lbfgs’, ‘liblinear’, ‘newton-cg’, ‘newton-cholesky’, ‘sag’, ‘saga’]:
#                 model = LogisticRegression(solver=solv)</code><br>
#       Эффективность была нулевая. f1-мера, precision, recall всегда имели одно и то же значение. Как я понял, это связано с тем, что логистическая регрессия имеет аналитическое решение (веса подбираются просто по формуле). Значит, большого смысла в переборе гиперпараметров нет. Собственно вопрос:<br>
#         По каким гиперпараметрам нужно варьироваться для исследования логистической регрессии?
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера №2<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# У логистической регрессии есть гиперпараметры, отвечающие за регуляризацию.
#
# Регуляризация - это техника, когда модель сама себя штрафует за неверные ответы.
#
# penalty{‘l1’, ‘l2’, ‘elasticnet’, None}, default=’l2’
#
# Этл гиперпараметр, который отвечает за вид регуляризации, различие в них состоит в их отношении к малозначимым признакам.
#
# L1 regularization, also known as L1 norm or Lasso (in regression problems), combats overfitting by shrinking the parameters towards 0. This makes some features obsolete.
#
# It’s a form of feature selection, because when we assign a feature with a 0 weight, we’re multiplying the feature values by 0 which returns 0, eradicating the significance of that feature. If the input features of our model have weights closer to 0, our L1 norm would be sparse. A selection of the input features would have weights equal to zero, and the rest would be non-zero.
#
# L2 regularization, or the L2 norm, or Ridge (in regression problems), combats overfitting by forcing weights to be small, but not making them exactly 0.
#
# https://neptune.ai/blog/fighting-overfitting-with-l1-or-l2-regularization#:~:text=The%20differences%20between%20L1%20and,regularization%20solution%20is%20non%2Dsparse.
#
# Cfloat, default=1.0
#
# Также есть параметр С, отвечающий за силу регуляризации.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %% [markdown]
# <div style="border: solid red 2px; background-color: rgba(50, 115, 220, 0.3); font-size: 18px">
#     При переборе по регуляризации возникало довольно много проблем.<br>
#     1. Некоторые `solver` работают только с определенными `penalty`<br>
#     2. Есть `solver=saga` который работает со всеми видами регуляризации, но он не сходился на 1000 итераций и время обучения улетало в космос. <br>
#     3. Решил перебрать только C параметр циклом из 10 итераций. f1-score изменялся только в 3 знаке, тем не менее, модель стала немного лучше!

# %% [markdown]
# ### Случайный лес

# %% [markdown]
# Для работы модели случайного леса нет необходимости в масштабировании признаков. Реализуем ее:

# %%
data_test_target = data.loc[data.index.isin(test_indexes)].is_canceled
data_test_features = data.loc[data.index.isin(test_indexes)]\
.drop(['is_canceled', 'season_coef', 'room_price', 'revenue', 'profit'], axis=1)
data_train_target = data.loc[data.index.isin(train_indexes)].is_canceled
data_train_features = data.loc[data.index.isin(train_indexes)]\
.drop(['is_canceled', 'season_coef', 'room_price', 'revenue', 'profit'], axis=1)

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black">Буду использовать и перебор гиперпараметров и кросс-валидацию. Лучшую модель отберу по максимальному f1-score</font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %%
def learn_rand_forest(features_train, target_train):
    best_forest_model = None
    full_scores = []
    best_f1_score = 0
    best_scores = []
    for depth in tqdm(range(5,12)):
        for est in range(1,51, 10):
            for leaf in range(1,5):
                #initialize model
                model = RandomForestClassifier(random_state=42, \
                    max_depth=depth, n_estimators=est, min_samples_leaf=leaf, class_weight='balanced')
                scoring = {'f1-score': 'f1',
                          'recall': 'recall',
                          'presicion': 'precision'}
                scores = cross_validate(model, features_train, target_train, cv=5, scoring=scoring)
                full_scores.append(scores)
                if scores['test_f1-score'].mean() > best_f1_score:
                    best_f1_score = scores['test_f1-score'].mean()
                    best_forest_model = model
                    best_scores = scores
    return best_forest_model, best_scores

# %%
best_forest_model, best_forest_scores = learn_rand_forest(data_train_features, data_train_target)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 7/7 [03:24<00:00, 29.17s/it]

# %%
best_forest_scores = pd.DataFrame(best_forest_scores)
best_forest_scores.mean().to_frame().rename(columns={0: 'Среднее значение'}).style.format('{:.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_bf273">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf273_level0_col0" class="col_heading level0 col0" >Среднее значение</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf273_level0_row0" class="row_heading level0 row0" >fit_time</th>
#       <td id="T_bf273_row0_col0" class="data row0 col0" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_bf273_level0_row1" class="row_heading level0 row1" >score_time</th>
#       <td id="T_bf273_row1_col0" class="data row1 col0" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_bf273_level0_row2" class="row_heading level0 row2" >test_f1-score</th>
#       <td id="T_bf273_row2_col0" class="data row2 col0" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_bf273_level0_row3" class="row_heading level0 row3" >test_recall</th>
#       <td id="T_bf273_row3_col0" class="data row3 col0" >0.59</td>
#     </tr>
#     <tr>
#       <th id="T_bf273_level0_row4" class="row_heading level0 row4" >test_presicion</th>
#       <td id="T_bf273_row4_col0" class="data row4 col0" >0.35</td>
#     </tr>
#   </tbody>
# </table>

# %%
pr_f1(list(best_forest_scores.loc[:, 'test_recall']),list(best_forest_scores.loc[:, 'test_presicion']) )
# Out:
# C:\Users\miros\AppData\Local\Temp\ipykernel_16564\1885180191.py:42: RuntimeWarning: invalid value encountered in true_divide
#   f1 = 2*x*y / (x+y)

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black">✍Модель случайного леса показала себя немного лучше. В среднем метрика recall достигает 0.58, значит мы находим почти 60% клиентов, собирающихся отменить бронь. f1-score - 0.41. При этом посмотрев на pr-график видно, что точки расположены не "кучно". Модель иногда показывает f1=0.62, а иногда f1=0.25. </font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера №2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Как минимум для 2х моделей стоит подобрать как минимум по 2 гиперпарметра

# %% [markdown]
# ### Модель максимальной прибыли

# %% [markdown]
# В моем понимании задание получилось несколько неполное. Получается, что введенный депозит для клиента выгоден всегда, потому что:
# 1. Клиент приехал = прибыль не изменилась
# 2. Клиент не приехал = убытки меньше
# В такой ситуации выгоднее всего просто сделать обязательный депозит `pred_is_cancelded = 1` для всех клиентов. Таким образом, мы максимизируем метрику recall и найдем всех "прогульщиков" и получим максимальную прибыль. Ведь нас никак не штрафуют за ошибки!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Да, но в таком случае можно отпугнуть потенциально новых клиентов и не проявить лояльности к старым. Людям будет проще забронировать гостиницу, где не будут постоянно требовать депозит.

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color = "black">✍Полностью согласен. Поэтому и обратил на это внимание </font>
#     <br />
#     <font size="3", color = "black">
# <br />

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера №2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>

# %% [markdown]
# <hr style="border: 2px solid blue;">

# %% [markdown]
# ### Тестирование лучшей модели

# %% [markdown]
# #### best_forest_model
#
# Модель случайного леса показала лучшие результаты в сравнении с логистической регрессией. Проверим ее на тестовых данных

# %%
data_test_target = data.loc[data.index.isin(test_indexes)].is_canceled
data_test_features = data.loc[data.index.isin(test_indexes)]\
.drop(['is_canceled', 'season_coef', 'room_price', 'revenue', 'profit'], axis=1)
data_train_target = data.loc[data.index.isin(train_indexes)].is_canceled
data_train_features = data.loc[data.index.isin(train_indexes)]\
.drop(['is_canceled', 'season_coef', 'room_price', 'revenue', 'profit'], axis=1)
data_test = data.loc[data.index.isin(test_indexes)]

# %%
best_forest_model.fit(data_train_features, data_train_target)
data_test.insert(0,column='pred_is_canceled', value=best_forest_model.predict(data_test_features))

# %% [markdown]
# #### Расчет потенциальной прибыли при введении депозитов

# %%
data_test['new_profit'] = (1 - data_test.is_canceled) \
    * data.profit + data_test.is_canceled * (1-data_test.pred_is_canceled) * \
        data_test.profit + data_test.is_canceled * data_test.pred_is_canceled * data_test.profit * 0.2
# Out:
# C:\Users\miros\AppData\Local\Temp\ipykernel_16564\2380786092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['new_profit'] = (1 - data_test.is_canceled) \

# %%
print(f'Прибыль компании до внедрения модели: {data_test.profit.sum():,.0f} руб\n\
Прибыль компании после внедрения модели: {data_test.new_profit.sum():,.0f} руб\n\
Прибыль за тестовый период увеличилась в \
{data_test.new_profit.sum() / data_test.profit.sum():.2f} раза или на \
{(data_test.new_profit.sum() - data_test.profit.sum()) / 10**6:.1f} млн руб')
# Out:
# Прибыль компании до внедрения модели: 31,765,140 руб
# Прибыль компании после внедрения модели: 36,271,524 руб
# Прибыль за тестовый период увеличилась в 1.14 раза или на 4.5 млн руб

# %%
print(classification_report(data_test.is_canceled, data_test.pred_is_canceled))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79     16405
#            1       0.54      0.56      0.55      7484
#
#     accuracy                           0.71     23889
#    macro avg       0.67      0.67      0.67     23889
# weighted avg       0.72      0.71      0.72     23889

# %% [markdown]
# ### Вывод по блоку "разработка ML модели"
# 1. Введение депозита с рассмотренной точки зрения исключительно положительный шаг. Прибыль всегда получит неотрицательный рост. В реальной жизни депозиты могут отпугивать клиентов от бронирования отеля и нужно это учитывать.
# 2. Модель случайного леса оказалась предпочтительнее, на тестовых данных f1-мера составила 0.56, а recall 0.58. Таким образом, почти в 60 % случаев удается значительно снизить издержки от отменивших бронь клиентов.
# 3. Прибыль компании после внедрения модели потенциально увеличться на 4.7 млн руб, что покроет затраты на разработку.

# %% [markdown]
# ## Шаг 5. Опишите портрет «ненадёжного» клиента

# %% [markdown]
# 1. Забронировал отель как можно раньше до заезда
# 2. Собирается приехать в высокий сезон (Лучше всего июнь)
# 3. В бронировании указано, что проживать планируют 2 взрослых
# 4. Бронирование сделанно из Португалии
# 5. Бронирование сделано через туроперато или турагента
# 6. Забронировал наиболее дорогой тип комнаты (A)
# 7. Бронирование подтверждено не сразу
# 8. Не является корпоративным клиентом

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Этот анализ можно провести опираясь теперь на важность признаков для модели.

# %% [markdown]
# ## Шаг 6. Напишите общий вывод

# %% [markdown]
# ### Общий вывод
#
# 1. Разработана система прогнозирования отказа от брони, окупающаяся за тестовый период
# 2. Оптимальной моделью на мой взгляд оказалась модель случайного леса. Позволяющая находить 60 % клиентов планирующих отменить бронь. Прибыль при использовании такой модели увеличивается на 15% или на 4.7 млн руб. При этом данная модель имеет точность дает верное предсказание по отмене брони в 53% случаев.
# 3. Наиболее важными характеристиками ненадежного клиента оказались:
# * Бронирование задолго до заезда
# * Бронирование сделано из Португалии
# * Подтверждение получено не сразу

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Общий вывод по проекту</b>
#
# Ярослав, спасибо за работу! Проект хороший, продуманный, структурно выдержанный. Однако стоит внести некоторые исправления, чтобы можно было считать работу завершенной.
#
# **Положительные моменты проекта, которые хочу еще раз подчеркнуть:**
#
# 1. Есть первичный анализ данных
# 2. Есть описание клиента склонного к отмене брони
# 3. Предобработка данных проводится корректно
# 4. Исследовано 2 модели  ML
# 5. Расчет прибыли до и после внедрения депозитов верный
#
# **Замечания, на которые стоит обратить внимание при будущей работе:**
#
#
#
#
#     1. Стоит выбрать подходящую метрику и написать обоснование выбора метрики
#     2. Стоит проверить целевую переменную на дисбаланс
#     3. Как минимум для 2х моделей стоит подобрать как минимум по 2 гиперпараметра
#     4. Расчет прибыли и проверку на тестовой выборке стоит проводить только для лучшей модели
#     5. Модели оценивать на кросс-валидации
#     6. Обработать неявные дубликаты в строковых данных
#     7. Исправить ошибку в коде
#
#
#
# Остальные комментарии ты найдешь выше.
#
# **Желаю удачи и жду твой проект на повторное ревью!**

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Общий вывод по проекту №2</b>
#
# Ярослав, спасибо за работу, ты молодец!
#
# Что осталось поправить:
#
#     1. Обрати, пожалуйста, внимание на столбец meal, там есть лишние пробелы в значениях.
#     2. По поводу гиперпараметров для логистической регрессии постаралась написать выше, советую попробовать использовать для подбора именно их.
#
# **Жду твой проект на следующее ревью**

# %% [markdown]
# <div style="border: solid red 2px; background-color: rgba(50, 115, 220, 0.3); font-size: 18px">
#     Вроде все поправил, спасибо большое!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Общий вывод по проекту №3</b>
#
# Ярослав, спасибо за работу!
#
# **Проект принимаю и желаю успехов в дальнейшем!**
